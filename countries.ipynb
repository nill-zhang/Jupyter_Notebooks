# %%
from mpl_toolkits.basemap import Basemap

# %%
import matplotlib.pyplot as ppt

# %%
mp = Basemap(projection="mill")

# %%
mp.drawcountries()

# %%
ppt.title("my first notebook example")

# %%
ppt.show()
